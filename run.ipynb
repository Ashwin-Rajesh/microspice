# %%
import microspice.microspice as usp

# %%
spice_netlist = "./examples/test3.sp"

# %%
s = usp.Microspice()

# %%
s.parse_and_run_file(spice_netlist)
# Out:
# [[ 1.e-03 -1.e-03  0.e+00  0.e+00  1.e+00]
#  [-1.e-03  2.e-03 -1.e-03  0.e+00  0.e+00]
#  [ 0.e+00 -1.e-03  1.e-03  0.e+00  0.e+00]
#  [ 0.e+00  0.e+00  1.e+05 -1.e+05  0.e+00]
#  [ 1.e+00  0.e+00  0.e+00  0.e+00  0.e+00]]
# [ 0.  0.  0.  0. 10.]
# V(0): [0.]
# V(1): 10.0
# V(2): 10.0
# V(3): 10.0
# V(4): 10.000000000111111
# [[ 1.e-03 -1.e-03  0.e+00  0.e+00  1.e+00]
#  [-1.e-03  2.e-03 -1.e-03  0.e+00  0.e+00]
#  [ 0.e+00 -1.e-03  1.e-03  0.e+00  0.e+00]
#  [ 0.e+00  0.e+00  1.e+05 -1.e+05  0.e+00]
#  [ 1.e+00  0.e+00  0.e+00  0.e+00  0.e+00]]
# [0. 0. 0. 0. 0.]
# V(0): [0.]
# V(1): 0.0
# V(2): 0.0
# V(3): 0.0
# V(4): 0.0
# [[ 1.e-03 -1.e-03  0.e+00  0.e+00  1.e+00]
#  [-1.e-03  2.e-03 -1.e-03  0.e+00  0.e+00]
#  [ 0.e+00 -1.e-03  1.e-03  0.e+00  0.e+00]
#  [ 0.e+00  0.e+00  1.e+05 -1.e+05  0.e+00]
#  [ 1.e+00  0.e+00  0.e+00  0.e+00  0.e+00]]
# [0. 0. 0. 0. 0.]
# V(0): [0.]
# V(1): 0.0
# V(2): 0.0
# V(3): 0.0
# V(4): 0.0
# [[ 1.e-03 -1.e-03  0.e+00  0.e+00  1.e+00]
# ...
